# %%
from google.colab import drive  

drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
data_image = np.load("/content/gdrive/MyDrive/CS329E Cloud Forecasting/Data_jrse/ForecastData/image_log_pred_test.npy")
# data_date = np.load("/content/gdrive/MyDrive/CS329E Cloud Forecasting/Data_jrse/ForecastData/datetime_log_trainval.npy", allow_pickle=True)
data_pv = np.load("/content/gdrive/MyDrive/CS329E Cloud Forecasting/Data_jrse/ForecastData/pv_log_test.npy", allow_pickle=True)
# data_image = np.load("/content/gdrive/MyDrive/CS329E Cloud Forecasting/Data_jrse/images_test.npy")
# data_date = np.load("/content/gdrive/MyDrive/CS329E Cloud Forecasting/Data_jrse/ForecastData/datetime_log_trainval.npy", allow_pickle=True)
# data_pv = np.load("/content/gdrive/MyDrive/CS329E Cloud Forecasting/Data_jrse/pv_log_test.npy", allow_pickle=True)
data_pred_pv = np.load("/content/gdrive/MyDrive/CS329E Cloud Forecasting/Data_jrse/ForecastData/pv_pred_test.npy", allow_pickle=True)

# %%
# data_image = data_image.reshape(data_image.shape[0]*data_image.shape[1],64,64,3)
# data_pv = data_pv.reshape(data_pv.shape[0] * data_pv.shape[1])

# %%
print(data_image.shape)
print(data_pv.shape)
# Out:
# (2542, 16, 64, 64, 3)
# (2542, 16)

# %%
# data_image = data_image.reshape(data_image.shape[0],64,64,48)
# norm = np.linalg.norm(data_image)
image_data = data_image/255
image_data = np.transpose(image_data,[0,2,3,1,4])
image_data = np.reshape(image_data, [image_data.shape[0],image_data.shape[1],image_data.shape[2],-1])

# %%
print(data_pred_pv)
# Out:
# [7.69873787 7.83045769 8.12693203 ... 0.20396781 0.1015716  0.02625455]

# %%
print(data_pred_pv.shape)
# print(data_pred_pv)
# Out:
# (2542,)

# %%
data_trainval = [image_data,data_pv]

# %%
########################################## add MODEL STEP
i = 0
model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_1/best_model_repitition_1.h5')
predictions = model.predict(data_trainval)
# model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_2/best_model_repitition_2.h5')
# predictions += model.predict(data_trainval)
# model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_2/best_model_repitition_2.h5')
# predictions += model.predict(data_trainval)
# model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_3/best_model_repitition_3.h5')
# predictions += model.predict(data_trainval)
# model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_4/best_model_repitition_4.h5')
# predictions += model.predict(data_trainval)
# model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_5/best_model_repitition_5.h5')
# predictions += model.predict(data_trainval)
# model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_6/best_model_repitition_6.h5')
# predictions += model.predict(data_trainval)
# model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_7/best_model_repitition_7.h5')
# predictions += model.predict(data_trainval)
# model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_8/best_model_repitition_8.h5')
# predictions += model.predict(data_trainval)
# model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_9/best_model_repitition_9.h5')
# predictions += model.predict(data_trainval)
# model = tf.keras.models.load_model('/content/gdrive/MyDrive/CS329E Cloud Forecasting/sunset_forecast_pretrained/repetition_10/best_model_repitition_10.h5')
# predictions += model.predict(data_trainval)

# %%
# print(predictions)
from sklearn.metrics import mean_squared_error
predictions = predictions

# %%
mean_squared_error(predictions, data_pred_pv)
# print(predictions)
# Out:
# 2.461600838388497
